# %%
import re
import numpy as np
import matplotlib as mat
import matplotlib.pyplot as plt
                    # to visualize 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report,f1_score,accuracy_score,confusion_matrix

from time import time
from sklearn.ensemble import AdaBoostClassifier

# %%
df=pd.read_csv("/content/drive/MyDrive/Project/toys_sample.csv")

# %%
df
# Out:
#          Unnamed: 0.1  Unnamed: 0  overall   reviewTime      reviewerID  \
# 0              722495      722495      1.0  11 26, 2014  A3373OHVS8TPJ0
# 1             4070772     4070772      1.0  03 26, 2015  A28G75XOL2ACWW
# 2             8104367     8104367      1.0  09 10, 2015  A2IVE814077NBT
# 3             7373301     7373301      1.0   08 8, 2016   AKNYDT3UZV9K3
# 4             7976280     7976280      1.0  05 13, 2017   A3FJZBAQTK1HU
# ...               ...         ...      ...          ...             ...
# 1678412       2648783     2648783      5.0   09 6, 2015   A21N2JUM77MY8
# 1678413       2976403     2976403      5.0  03 27, 2016  A3TUPD6NVVEFE4
# 1678414       6803955     6803955      5.0  12 21, 2016  A35RC23MZDOUV2
# 1678415       5048421     5048421      5.0  09 15, 2015   A6J0A3APZFS4T
# 1678416        774339      774339      5.0   11 4, 2015  A1ZYW9B7HF71KW
#
#                asin        reviewerName  \
# 0        B000F3V2MW          Clovergirl
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# overall            0
# reviewTime         0
# reviewerID         0
# asin               0
# reviewerName       0
# reviewText      1742
# brand            131
# main_cat           0
# Polarity           0
# Analysis           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
x=df['reviewText']
y=df['Analysis']

# %%
cv = TfidfVectorizer()
x = cv.fit_transform(x)

# %%
x_train ,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20 ,random_state=0)

# %%
t=time()
lr1=LogisticRegression(max_iter=100)
ovr1=OneVsRestClassifier(lr1)
ovr1.fit(x_train,y_train)

y_pred=ovr1.predict(x_test)

end=time()-t

print(end)
# Out:
# 92.3583767414093

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.95      0.93     34306
#      Neutral       0.95      0.97      0.96     28524
#     Positive       0.99      0.98      0.99    272479
#
#     accuracy                           0.98    335309
#    macro avg       0.95      0.97      0.96    335309
# weighted avg       0.98      0.98      0.98    335309

# %%
dic={"actual":y_test[:31],"predicted":y_pred[:31]}  
pd.DataFrame(dic)
# Out:
#            actual predicted
# 1347586  Positive  Positive
# 482299   Positive  Positive
# 620701   Positive  Positive
# 282426    Neutral   Neutral
# 720698   Positive  Positive
# 23118    Negative  Negative
# 628422   Positive  Positive
# 1618431  Negative  Negative
# 1498727  Positive  Positive
# 233821    Neutral   Neutral
# 412870   Positive  Positive
# 1261843  Positive  Positive
# 39407    Negative  Negative
# 408921   Positive  Positive
# 492682   Positive  Positive
# 1520418  Positive  Positive
# 459868   Positive  Positive
# 832776   Positive  Positive
# 1399033  Positive  Positive
# 430085   Positive  Positive
# 1521381  Positive  Positive
# 266970   Positive  Positive
# 105506   Negative  Negative
# 19569    Positive  Positive
# 558063   Positive  Positive
# 531009   Positive  Positive
# 1432660  Positive  Positive
# 835057   Positive  Positive
# 322443   Positive  Positive
# 166817   Positive  Positive
# 1582952  Positive  Positive
